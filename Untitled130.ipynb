# %% [markdown]
# <a href="https://colab.research.google.com/github/spencersgoogle/kaggleimages/blob/main/Untitled130.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'col1': [1, 2, 3, 4],
    'col2': ['A', 'B', 'C', 'D']
}
df = pd.DataFrame(data)
print(df)
# Out:
#    col1 col2
# 0     1    A
# 1     2    B
# 2     3    C
# 3     4    D

# %%
# dataframe: df
# uuid: 7ABEC2AC-7BD9-47DA-AA69-5FBEB4F841C9
# output_variable:
# config_str: ...

import google.colabsqlviz.explore_dataframe as _vizcell
_vizcell.explore_dataframe(df_or_df_name='df', uuid='7ABEC2AC-7BD9-47DA-AA69-5FBEB4F841C9', config_str='...')
